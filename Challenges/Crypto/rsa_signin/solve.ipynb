# %%
# 解法一 直接gcd
from math import gcd
c1 = ...
n1 = ...
n2 = ...
p = gcd(n1, n2)
q = n1 // p
e = 65537
phi = (p - 1) * (q - 1)
d = pow(e, -1, phi)
m = pow(c1, d, n1)
print(m.to_bytes((m.bit_length() + 7) // 8, "big"))
# Out:
# b'moectf{it_is_re@lly_@_signin_level_cryPto_ch@ll@nge_ng92WPIBung92WPIBun}'
