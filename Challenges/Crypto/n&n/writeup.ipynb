# %% [markdown]
# # Writeup
#
# by koito
#
# 直接共模攻击，用欧几里得算法

# %%
import gmpy2
from Crypto.Util.number import *
e1 = 0x114514
e2 = 19198101
c1 = ...
c2 = ...
n = ...
g,x,y = gmpy2.gcdext(e1,e2)
print(long_to_bytes((pow(c1,x,n) * pow(c2,y,n))%n))
# Out:
# b'moectf{dO_nOt_u53_5AM3_MOdulu5_tO_3ncrYPt_dIFF3r3nt_dAtA!_JY63x33iiA0Ji}'
